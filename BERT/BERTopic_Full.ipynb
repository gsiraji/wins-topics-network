# %% [markdown]
# # BERTopic

# %%
from bertopic import BERTopic
# Out:
# /Users/moyi/opt/anaconda3/envs/wins-project-bert/lib/python3.8/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /Users/moyi/opt/anaconda3/envs/wins-project-bert/lib/python3.8/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /Users/moyi/opt/anaconda3/envs/wins-project-bert/lib/python3.8/site-packages/umap/distances.py:1086: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /Users/moyi/opt/anaconda3/envs/wins-project-bert/lib/python3.8/site-packages/umap/umap_.py:660: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# 2023-06-12 10:59:36.759823: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import json

# %%
import plotly.io as pio
pio.renderers.default = "svg"

# %% [markdown]
# ## Load Data

# %%
with open('preprocessed_data.json', 'r') as f:
    data = json.load(f)

# %%
data.keys()
# Out:
# dict_keys(['climate_change_abstract', 'climate_change_title', 'nlp_abstract', 'nlp_title'])

# %%
cc_abs = data['climate_change_abstract']
cc_ttl = data['climate_change_title']
nlp_abs = data['nlp_abstract']
nlp_ttl = data['nlp_title']

# %% [markdown]
# ## Climate Change

# %% [markdown]
# ## Abstract

# %%
cc_topic_model = BERTopic()

# %%
cc_topics, cc_probs = cc_topic_model.fit_transform(cc_abs)

# %%
cc_topic_model.get_topic_info()
# Out:
#     Topic  Count                                       Name  \
# 0      -1    557                -1_climate_change_model_use
# 1       0    159          0_energy_power_electricity_system
# 2       1    110          1_specie_population_forest_change
# 3       2    103           2_solar_temperature_global_cycle
# 4       3     76                3_opinion_topic_user_change
# 5       4     63          4_image_dataset_remotesense_datum
# 6       5     58       5_crop_agricultural_agriculture_food
# 7       6     45            6_climate_response_model_system
# 8       7     38        7_precipitation_weather_model_datum
# 9       8     37              8_ice_seaice_model_projection
# 10      9     36          9_research_climate_science_change
# 11     10     30   10_rainfall_drought_precipitation_region
# 12     11     28            11_wildfire_fire_detection_risk
# 13     12     24    12_methane_emission_satellite_pollutant
# 14     13     23    13_model_projection_uncertainty_climate
# 15     14     23             14_co_adsorption_material_dope
# 16     15     22                15_policy_model_damage_rate
# 17     16     20        16_disaster_network_flood_hurricane
# 18     17     19                    17_urban_city_tree_heat
# 19     18     18  18_extreme_event_distribution_temperature
# 20     19     16           19_forest_deforestation_tree_map
# 21     20     16        20_disease_spread_rainfall_mosquito
# 22     21     15      21_civilization_energy_global_warming
# 23     22     15             22_gasmixture_detector_gas_rpc
# 24     23     13           23_co_injection_storage_pressure
# 25     24     12              24_carbon_cost_price_emission
# 26     25     12            25_emission_co_drainage_methane
#
#                                        Representation  \
# 0   [climate, change, model, use, global, datum, t...
# 1   [energy, power, electricity, system, wind, dem...
# 2   [specie, population, forest, change, climate, ...
# 3   [solar, temperature, global, cycle, earth, war...
# 4   [opinion, topic, user, change, climate, twitte...
# 5   [image, dataset, remotesense, datum, method, m...
# 6   [crop, agricultural, agriculture, food, yield,...
# 7   [climate, response, model, system, change, equ...
# 8   [precipitation, weather, model, datum, extreme...
# 9   [ice, seaice, model, projection, sealevel, oce...
# 10  [research, climate, science, change, policy, s...
# 11  [rainfall, drought, precipitation, region, tre...
# 12  [wildfire, fire, detection, risk, model, burn,...
# 13  [methane, emission, satellite, pollutant, pred...
# 14  [model, projection, uncertainty, climate, baye...
# 15  [co, adsorption, material, dope, reaction, hig...
# 16  [policy, model, damage, rate, decision, iam, c...
# 17  [disaster, network, flood, hurricane, vulnerab...
# 18  [urban, city, tree, heat, street, building, mi...
# 19  [extreme, event, distribution, temperature, sh...
# 20  [forest, deforestation, tree, map, lidar, accu...
# 21  [disease, spread, rainfall, mosquito, pandemic...
# 22  [civilization, energy, global, warming, climat...
# 23  [gasmixture, detector, gas, rpc, mixture, cern...
# 24  [co, injection, storage, pressure, aquifer, se...
# 25  [carbon, cost, price, emission, financial, mar...
# 26  [emission, co, drainage, methane, global, perc...
#
#                                   Representative_Docs
# 0   [climate change impact study inform policymake...
# 1   [several research study show future sustainabl...
# 2   [change frequency duration severity climate ex...
# 3   [compare performance recently propose empirica...
# 4   [twitter account already use many scientometri...
# 5   [climate change increase frequency severity ha...
# 6   [world population increase demand food demand ...
# 7   [equilibrium climate sensitivity ecs key predi...
# 8   [impact extreme heat dome society biodiversity...
# 9   [climate simulation paleoclimate datum modern ...
# 10  [humanitarian challenge include natural_disast...
# 11  [climate model robustly imply significant chan...
# 12  [research show climate change create warm temp...
# 13  [coal mine globally important source methane a...
# 14  [quantify risk global warming exceed critical ...
# 15  [global warming see drastic environmental prob...
# 16  [work base framework propose determine optimal...
# 17  [social_media data aid disaster response damag...
# 18  [rapid population growth climate change drive ...
# 19  [rapid change climatic condition threaten soci...
# 20  [propose inference use satellite image time_se...
# 21  [fever disease cause crimean virus cchfv tick ...
# 22  [level technological development civilization ...
# 23  [resistive_plate chamber rpc use muon spectrom...
# 24  [carbon_dioxide co injection saline aquifer me...
# 25  [climate change global warming significant cha...
# 26  [diurnal cycle co emission combustion cement p...

# %%
cc_topic_model.get_topic(0)
# Out:
# [('energy', 0.04598772595377279),
#  ('power', 0.034134293964418014),
#  ('electricity', 0.030784002561929705),
#  ('system', 0.03020234375372471),
#  ('wind', 0.023273883987999195),
#  ('demand', 0.018994703415714107),
#  ('generation', 0.01860338962395847),
#  ('emission', 0.017505631036394954),
#  ('renewableenergy', 0.015949175930985007),
#  ('cost', 0.015400416265160182)]

# %%
cc_topic_model.get_document_info(cc_abs)
# Out:
#                                                Document  Topic  \
# 0     sun role earth recent warming remain controver...     -1
# 1     recent analysis indicate amount atmospheric co...     -1
# 2     claim other observe temporal correlation terre...      2
# 3     claim unanimity scientific community human cul...      3
# 4     promote increase energy efficiency promise met...     -1
# ...                                                 ...    ...
# 1583  investigate issue dangerous human make interfe...     -1
# 1584  climate response anthropogenic force long domi...     -1
# 1585  propose galactic cosmic_ray influence earth cl...      2
# 1586  present intercomparison verification analysis ...     10
# 1587  climate change require construction barrier se...     16
#
#                                           Name  \
# 0                  -1_climate_change_model_use
# 1                  -1_climate_change_model_use
# 2             2_solar_temperature_global_cycle
# 3                  3_opinion_topic_user_change
# 4                  -1_climate_change_model_use
# ...                                        ...
# 1583               -1_climate_change_model_use
# 1584               -1_climate_change_model_use
# 1585          2_solar_temperature_global_cycle
# 1586  10_rainfall_drought_precipitation_region
# 1587       16_disaster_network_flood_hurricane
#
#                                          Representation  \
# 0     [climate, change, model, use, global, datum, t...
# 1     [climate, change, model, use, global, datum, t...
# 2     [solar, temperature, global, cycle, earth, war...
# 3     [opinion, topic, user, change, climate, twitte...
# 4     [climate, change, model, use, global, datum, t...
# ...                                                 ...
# 1583  [climate, change, model, use, global, datum, t...
# 1584  [climate, change, model, use, global, datum, t...
# 1585  [solar, temperature, global, cycle, earth, war...
# 1586  [rainfall, drought, precipitation, region, tre...
# 1587  [disaster, network, flood, hurricane, vulnerab...
#
#                                     Representative_Docs  \
# 0     [climate change impact study inform policymake...
# 1     [climate change impact study inform policymake...
# 2     [compare performance recently propose empirica...
# 3     [twitter account already use many scientometri...
# 4     [climate change impact study inform policymake...
# ...                                                 ...
# 1583  [climate change impact study inform policymake...
# 1584  [climate change impact study inform policymake...
# 1585  [compare performance recently propose empirica...
# 1586  [climate model robustly imply significant chan...
# 1587  [social_media data aid disaster response damag...
#
#                                             Top_n_words  Probability  \
# 0     climate - change - model - use - global - datu...     0.000000
# 1     climate - change - model - use - global - datu...     0.000000
# 2     solar - temperature - global - cycle - earth -...     0.435841
# 3     opinion - topic - user - change - climate - tw...     0.822165
# 4     climate - change - model - use - global - datu...     0.000000
# ...                                                 ...          ...
# 1583  climate - change - model - use - global - datu...     0.000000
# 1584  climate - change - model - use - global - datu...     0.000000
# 1585  solar - temperature - global - cycle - earth -...     0.434762
# 1586  rainfall - drought - precipitation - region - ...     0.457577
# 1587  disaster - network - flood - hurricane - vulne...     0.608392
#
#       Representative_document
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 1583                    False
# 1584                    False
# 1585                    False
# 1586                    False
# 1587                    False
#
# [1588 rows x 8 columns]

# %%
cc_topic_model.visualize_topics()
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %% [markdown]
# ## Title

# %%
cc_ttl_topic_model = BERTopic()

# %%
cc_ttl_topics, cc_ttl_probs = cc_ttl_topic_model.fit_transform(cc_ttl)

# %%
cc_ttl_topic_model.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0      -1    676                        -1_climate_change_model_use
# 1       0    109                 0_global_temperature_warming_model
# 2       1     63            1_deep_learning_forecast_classification
# 3       2     61                    2_power_charge_grid_electricity
# 4       3     51              3_opinion_twitter_socialmedia_dynamic
# 5       4     49                     4_climate_change_new_dangerous
# 6       5     42           5_extinction_ecosystem_population_specie
# 7       6     40                 6_solar_irradiance_sun_terrestrial
# 8       7     38                 7_carbon_footprint_emission_market
# 9       8     38             8_extreme_precipitation_river_rainfall
# 10      9     35                          9_ice_sheet_polar_retreat
# 11     10     35                     10_flood_disaster_risk_machine
# 12     11     33            11_economic_uncertainty_economy_climate
# 13     12     32                     12_forest_tree_mangrove_carbon
# 14     13     31                13_wildfire_fire_detection_wildland
# 15     14     30                    14_carbon_liquid_metal_hydrogen
# 16     15     29  15_environmental_sustainable_sustainability_se...
# 17     16     24            16_energy_renewable_nuclear_electricity
# 18     17     21             17_quantile_linear_causality_timeserie
# 19     18     18                18_sealevel_rise_error_acceleration
# 20     19     15              19_rice_farm_agricultural_agriculture
# 21     20     15                      20_aerosol_dust_size_transfer
# 22     21     14  21_artificialintelligence_ai_cooperation_election
# 23     22     13              22_reinforcement_learning_deep_design
# 24     23     12          23_bibliometric_research_literature_topic
# 25     24     11   24_spatiotemporal_spatial_bayesian_palaeoclimate
# 26     25     11             25_knowledge_civilization_avoid_filter
# 27     26     11                     26_methane_gas_source_emission
# 28     27     11       27_robotic_agriculture_agricultural_wireless
# 29     28     10                  28_reef_computervision_coral_fish
# 30     29     10                  29_datum_topological_sequence_see
#
#                                        Representation  \
# 0   [climate, change, model, use, base, datum, sys...
# 1   [global, temperature, warming, model, climate,...
# 2   [deep, learning, forecast, classification, con...
# 3   [power, charge, grid, electricity, smart, elec...
# 4   [opinion, twitter, socialmedia, dynamic, news,...
# 5   [climate, change, new, dangerous, science, res...
# 6   [extinction, ecosystem, population, specie, tr...
# 7   [solar, irradiance, sun, terrestrial, radiatio...
# 8   [carbon, footprint, emission, market, tax, com...
# 9   [extreme, precipitation, river, rainfall, mode...
# 10  [ice, sheet, polar, retreat, antarctic, arctic...
# 11  [flood, disaster, risk, machine, hazard, natur...
# 12  [economic, uncertainty, economy, climate, risk...
# 13  [forest, tree, mangrove, carbon, effect, tropi...
# 14  [wildfire, fire, detection, wildland, remotese...
# 15  [carbon, liquid, metal, hydrogen, molecular, c...
# 16  [environmental, sustainable, sustainability, s...
# 17  [energy, renewable, nuclear, electricity, powe...
# 18  [quantile, linear, causality, timeserie, respo...
# 19  [sealevel, rise, error, acceleration, warming,...
# 20  [rice, farm, agricultural, agriculture, corn, ...
# 21  [aerosol, dust, size, transfer, radiative, poi...
# 22  [artificialintelligence, ai, cooperation, elec...
# 23  [reinforcement, learning, deep, design, explor...
# 24  [bibliometric, research, literature, topic, pu...
# 25  [spatiotemporal, spatial, bayesian, palaeoclim...
# 26  [knowledge, civilization, avoid, filter, effec...
# 27  [methane, gas, source, emission, harsh, ultra,...
# 28  [robotic, agriculture, agricultural, wireless,...
# 29  [reef, computervision, coral, fish, fine, surv...
# 30  [datum, topological, sequence, see, sdm, artir...
#
#                                   Representative_Docs
# 0   [diffusion model climate change, impact climat...
# 1   [estimate trend global mean temperature record...
# 2   [inference climate change event satellite imag...
# 3   [decarbonize demand response residential elect...
# 4   [understand people need view diverse social op...
# 5   [review effect climate change, dangerous human...
# 6   [risk population extinction periodic abrupt ch...
# 7   [solar modeling, new approach reconstruction s...
# 8   [green algorithm quantify carbon footprint com...
# 9   [physics guide probabilistic modeling extreme ...
# 10  [estimate globe warming cause retreat polar se...
# 11  [integration flood base approach, global flood...
# 12  [complexity economic science possible economic...
# 13  [predict whole forest structure primary produc...
# 14  [image base early detection system wildfire, w...
# 15  [integration hydrothermal liquefaction carbon ...
# 16  [methodology assess environmental effect induc...
# 17  [power system decarbonization impact energy st...
# 18  [local linear quantile estimation time_serie, ...
# 19  [reply benestad comment discussion common erro...
# 20  [influence climate change corn yield ontario i...
# 21  [small desert dust cool effect estimate analys...
# 22  [mapping climate change research open reposito...
# 23  [optimization reinforcement learning, climate ...
# 24  [climate change research view bibliometric, la...
# 25  [combine interdependent climate model spatial ...
# 26  [avoid great filter predict timeline humanity ...
# 27  [meter sensor earth observation benchmark auto...
# 28  [robotic tankette intelligent agriculture desi...
# 29  [framework reef mapping clustering method remo...
# 30  [vconstruct fill gap datum use variational aut...

# %%
cc_ttl_topic_model.get_topic(0)
# Out:
# [('global', 0.08265584880411103),
#  ('temperature', 0.08110338587026988),
#  ('warming', 0.0780152197614667),
#  ('model', 0.03389511109685561),
#  ('climate', 0.03341928389869434),
#  ('surface', 0.030800321858036106),
#  ('trend', 0.029669051180529118),
#  ('circulation', 0.028002662643580586),
#  ('earth', 0.027873492000492994),
#  ('oscillation', 0.026497487043319497)]

# %%
cc_ttl_topic_model.get_document_info(cc_ttl)
# Out:
#                                                Document  Topic  \
# 0                               climate change sun role      6
# 1                        avert dangerous climate change      4
# 2                                        global warming      0
# 3                 global warming sacrificial temptation      0
# 4     tackle climate change energy efficiency mathem...     -1
# ...                                                 ...    ...
# 1583    dangerous human make interference climate study      4
# 1584                   believe high climate sensitivity      4
# 1585                                         cosmic_ray     -1
# 1586  danube exist version reality give various regi...      8
# 1587                      textile barrier preserve rise     -1
#
#                                         Name  \
# 0         6_solar_irradiance_sun_terrestrial
# 1             4_climate_change_new_dangerous
# 2         0_global_temperature_warming_model
# 3         0_global_temperature_warming_model
# 4                -1_climate_change_model_use
# ...                                      ...
# 1583          4_climate_change_new_dangerous
# 1584          4_climate_change_new_dangerous
# 1585             -1_climate_change_model_use
# 1586  8_extreme_precipitation_river_rainfall
# 1587             -1_climate_change_model_use
#
#                                          Representation  \
# 0     [solar, irradiance, sun, terrestrial, radiatio...
# 1     [climate, change, new, dangerous, science, res...
# 2     [global, temperature, warming, model, climate,...
# 3     [global, temperature, warming, model, climate,...
# 4     [climate, change, model, use, base, datum, sys...
# ...                                                 ...
# 1583  [climate, change, new, dangerous, science, res...
# 1584  [climate, change, new, dangerous, science, res...
# 1585  [climate, change, model, use, base, datum, sys...
# 1586  [extreme, precipitation, river, rainfall, mode...
# 1587  [climate, change, model, use, base, datum, sys...
#
#                                     Representative_Docs  \
# 0     [solar modeling, new approach reconstruction s...
# 1     [review effect climate change, dangerous human...
# 2     [estimate trend global mean temperature record...
# 3     [estimate trend global mean temperature record...
# 4     [diffusion model climate change, impact climat...
# ...                                                 ...
# 1583  [review effect climate change, dangerous human...
# 1584  [review effect climate change, dangerous human...
# 1585  [diffusion model climate change, impact climat...
# 1586  [physics guide probabilistic modeling extreme ...
# 1587  [diffusion model climate change, impact climat...
#
#                                             Top_n_words  Probability  \
# 0     solar - irradiance - sun - terrestrial - radia...     0.684991
# 1     climate - change - new - dangerous - science -...     0.983457
# 2     global - temperature - warming - model - clima...     1.000000
# 3     global - temperature - warming - model - clima...     1.000000
# 4     climate - change - model - use - base - datum ...     0.000000
# ...                                                 ...          ...
# 1583  climate - change - new - dangerous - science -...     1.000000
# 1584  climate - change - new - dangerous - science -...     0.799124
# 1585  climate - change - model - use - base - datum ...     0.000000
# 1586  extreme - precipitation - river - rainfall - m...     0.644364
# 1587  climate - change - model - use - base - datum ...     0.000000
#
#       Representative_document
# 0                       False
# 1                       False
# 2                        True
# 3                       False
# 4                       False
# ...                       ...
# 1583                     True
# 1584                    False
# 1585                    False
# 1586                    False
# 1587                    False
#
# [1588 rows x 8 columns]

# %%
cc_ttl_topic_model.visualize_topics()

# %% [markdown]
# ## NLP

# %% [markdown]
# ## Abstract

# %%
nlp_topic_model = BERTopic()

# %%
nlp_topics, nlp_probs = nlp_topic_model.fit_transform(nlp_abs)

# %%
nlp_topic_model.get_topic_info()
# Out:
#      Topic  Count                                               Name  \
# 0       -1   3807                       -1_model_language_task_datum
# 1        0    522              0_clinical_medical_patient_biomedical
# 2        1    373                      1_embedding_word_embed_vector
# 3        2    187                     2_bias_gender_fairness_debiase
# 4        3    169  3_adversarial_attack_adversarialexample_robust...
# ..     ...    ...                                                ...
# 135    134     11                     134_moral_ethical_morality_llm
# 136    135     11  135_cluster_clustering_brownclustere_hierarchical
# 137    136     11                   136_formality_action_long_editor
# 138    137     11            137_speech_transformer_audio_positional
# 139    138     10      138_programming_revision_logicprogramme_logic
#
#                                         Representation  \
# 0    [model, language, task, datum, natural, learn,...
# 1    [clinical, medical, patient, biomedical, disea...
# 2    [embedding, word, embed, vector, representatio...
# 3    [bias, gender, fairness, debiase, genderbia, s...
# 4    [adversarial, attack, adversarialexample, robu...
# ..                                                 ...
# 135  [moral, ethical, morality, llm, ethic, value, ...
# 136  [cluster, clustering, brownclustere, hierarchi...
# 137  [formality, action, long, editor, swap, sequen...
# 138  [speech, transformer, audio, positional, pool,...
# 139  [programming, revision, logicprogramme, logic,...
#
#                                    Representative_Docs
# 0    [classification essential fundamental task mac...
# 1    [pre training show success different area mach...
# 2    [understand human language sub challenge way i...
# 3    [last_year word sentence embedding establish t...
# 4    [robustness huge transformer base model natura...
# ..                                                 ...
# 135  [morality play important role culture identity...
# 136  [paper describe research method generate word ...
# 137  [task receive remarkable attention wide applic...
# 138  [transformer gain increase popularity wide_ran...
# 139  [international event present research logic_pr...
#
# [140 rows x 5 columns]

# %%
nlp_topic_model.get_topic(47)
# Out:
# [('similarity', 0.09468439061012217),
#  ('semantic', 0.041832360309283105),
#  ('measure', 0.02949264243353747),
#  ('sentence', 0.021417082257691154),
#  ('pair', 0.01708546470451544),
#  ('relatedness', 0.01579136947770174),
#  ('equivalence', 0.01424118276831733),
#  ('metric', 0.01246869636497091),
#  ('collision', 0.011800979119164971),
#  ('word', 0.01110579393792444)]

# %%
nlp_topic_model.get_document_info(nlp_abs)
# Out:
#                                                Document  Topic  \
# 0     intelligent input method m essential make text...     -1
# 1     web semantic access specific domain call speci...     52
# 2     spatial coherence measure variable temperature...     29
# 3     investigate soliton structure novel dimensiona...    106
# 4     extract process abstract datum sfn annual meet...     -1
# ...                                                 ...    ...
# 9773  priority programme language speech technology ...     -1
# 9774  paper describe robust parse technique fruitful...      9
# 9775  system describe use mixed level representation...     90
# 9776  system describe use mixed level knowledge repr...     90
# 9777  paper describe detail discrete quaternion abst...     36
#
#                                               Name  \
# 0                     -1_model_language_task_datum
# 1                52_query_search_ontology_semantic
# 2              29_matrix_probabilistic_linear_tree
# 3     106_equation_coefficient_nlpde_laxintegrable
# 4                     -1_model_language_task_datum
# ...                                            ...
# 9773                  -1_model_language_task_datum
# 9774                 9_parse_parser_tree_syntactic
# 9775   90_contradiction_inheritance_hierarchy_rule
# 9776   90_contradiction_inheritance_hierarchy_rule
# 9777       36_quantum_discocat_qnlp_quantumcircuit
#
#                                          Representation  \
# 0     [model, language, task, datum, natural, learn,...
# 1     [query, search, ontology, semantic, web, searc...
# 2     [matrix, probabilistic, linear, tree, hmms, wa...
# 3     [equation, coefficient, nlpde, laxintegrable, ...
# 4     [model, language, task, datum, natural, learn,...
# ...                                                 ...
# 9773  [model, language, task, datum, natural, learn,...
# 9774  [parse, parser, tree, syntactic, semantic, par...
# 9775  [contradiction, inheritance, hierarchy, rule, ...
# 9776  [contradiction, inheritance, hierarchy, rule, ...
# 9777  [quantum, discocat, qnlp, quantumcircuit, clas...
#
#                                     Representative_Docs  \
# 0     [classification essential fundamental task mac...
# 1     [many search system work large amount natural ...
# 2     [thesis present approach rigorous mathematical...
# 3     [variable coefficient vrie modify vrie nonline...
# 4     [classification essential fundamental task mac...
# ...                                                 ...
# 9773  [classification essential fundamental task mac...
# 9774  [traditional nlp long hold supervised syntacti...
# 9775  [task differ semantic information require time...
# 9776  [task differ semantic information require time...
# 9777  [machine learning achieve dramatic success pas...
#
#                                             Top_n_words  Probability  \
# 0     model - language - task - datum - natural - le...     0.000000
# 1     query - search - ontology - semantic - web - s...     1.000000
# 2     matrix - probabilistic - linear - tree - hmms ...     0.650942
# 3     equation - coefficient - nlpde - laxintegrable...     1.000000
# 4     model - language - task - datum - natural - le...     0.000000
# ...                                                 ...          ...
# 9773  model - language - task - datum - natural - le...     0.000000
# 9774  parse - parser - tree - syntactic - semantic -...     0.811594
# 9775  contradiction - inheritance - hierarchy - rule...     1.000000
# 9776  contradiction - inheritance - hierarchy - rule...     1.000000
# 9777  quantum - discocat - qnlp - quantumcircuit - c...     0.865376
#
#       Representative_document
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 9773                    False
# 9774                    False
# 9775                    False
# 9776                    False
# 9777                    False
#
# [9778 rows x 8 columns]

# %%
nlp_topic_model.visualize_topics()

# %% [markdown]
# ## Title

# %%
nlp_ttl_topic_model = BERTopic()

# %%
nlp_ttl_topics, nlp_ttl_probs = nlp_ttl_topic_model.fit_transform(nlp_ttl)

# %%
nlp_ttl_topic_model.get_topic_info()
# Out:
#      Topic  Count                                             Name  \
# 0       -1   3010       -1_language_network_natural_representation
# 1        0    398            0_clinical_biomedical_medical_patient
# 2        1    218            1_datum_augmentation_drive_collection
# 3        2    184  2_adversarial_attack_adversarialexample_defense
# 4        3    172              3_attention_self_mechanism_saliency
# ..     ...    ...                                              ...
# 147    146     11          146_context_example_generalist_remember
# 148    147     11             147_segmentation_image_medical_tumor
# 149    148     10            148_architecture_search_flow_lyapunov
# 150    149     10           149_entity_expansion_set_gaussetexpand
# 151    150     10              150_downstream_task_hyperembe_treat
#
#                                         Representation  \
# 0    [language, network, natural, representation, m...
# 1    [clinical, biomedical, medical, patient, recor...
# 2    [datum, augmentation, drive, collection, big, ...
# 3    [adversarial, attack, adversarialexample, defe...
# 4    [attention, self, mechanism, saliency, head, g...
# ..                                                 ...
# 147  [context, example, generalist, remember, good,...
# 148  [segmentation, image, medical, tumor, segment,...
# 149  [architecture, search, flow, lyapunov, incompr...
# 150  [entity, expansion, set, gaussetexpand, muver,...
# 151  [downstream, task, hyperembe, treat, hyper, we...
#
#                                    Representative_Docs
# 0    [base language model, survey natural language ...
# 1    [survey embedding clinical natural language pr...
# 2    [datum augmentation approach natural language ...
# 3    [robust textual embed word level adversarial a...
# 4    [pretraine attention, attention natural langua...
# ..                                                 ...
# 147  [make good context example gpt, make good exam...
# 148  [network medical image segmentation, transform...
# 149  [light accurate neural architecture search con...
# 150  [automatic context pattern generation entity s...
# 151  [word optimal hyper parameter impact nlp downs...
#
# [152 rows x 5 columns]

# %%
nlp_ttl_topic_model.get_topic(0)
# Out:
# [('clinical', 0.05111784588694772),
#  ('biomedical', 0.0386642689576386),
#  ('medical', 0.03704149609206024),
#  ('patient', 0.024247518374262547),
#  ('record', 0.022524250812798484),
#  ('clinicalnote', 0.018325144745921697),
#  ('drug', 0.017408887508625612),
#  ('disease', 0.0163259745777937),
#  ('extraction', 0.014552105746520954),
#  ('report', 0.013292105891718187)]

# %%
nlp_ttl_topic_model.get_document_info(nlp_ttl)
# Out:
#                                                Document  Topic  \
# 0          development text input method lessons_learne     -1
# 1     robust linguistic platform efficient domain sp...     -1
# 2     detect spatial pattern cumulant function appli...     -1
# 3     structure high order dimensional equation rela...     -1
# 4     analysis abstract present annual meeting socie...    132
# ...                                                 ...    ...
# 9773         evaluation component speak dialogue system      7
# 9774  semantic robust parse noun extraction natural ...     13
# 9775  deduction mixed level logic representation tex...     73
# 9776  mixed level knowledge representation variable ...     76
# 9777             combinatorial bit bang lead quaternion    100
#
#                                                Name  \
# 0        -1_language_network_natural_representation
# 1        -1_language_network_natural_representation
# 2        -1_language_network_natural_representation
# 3        -1_language_network_natural_representation
# 4                132_neuron_dendrite_typilus_apical
# ...                                             ...
# 9773  7_dialogue_dialog_conversational_conversation
# 9774        13_parse_dependencyparse_parser_parsing
# 9775  73_logic_programming_constraint_international
# 9776   76_inference_natural_reasoning_statistically
# 9777                 100_quantum_computer_move_term
#
#                                          Representation  \
# 0     [language, network, natural, representation, m...
# 1     [language, network, natural, representation, m...
# 2     [language, network, natural, representation, m...
# 3     [language, network, natural, representation, m...
# 4     [neuron, dendrite, typilus, apical, neuronbloc...
# ...                                                 ...
# 9773  [dialogue, dialog, conversational, conversatio...
# 9774  [parse, dependencyparse, parser, parsing, depe...
# 9775  [logic, programming, constraint, international...
# 9776  [inference, natural, reasoning, statistically,...
# 9777  [quantum, computer, move, term, categorical, f...
#
#                                     Representative_Docs  \
# 0     [base language model, survey natural language ...
# 1     [base language model, survey natural language ...
# 2     [base language model, survey natural language ...
# 3     [base language model, survey natural language ...
# 4     [ask neuron neural base approach answer questi...
# ...                                                 ...
# 9773  [training inference dialogue, base mixture_exp...
# 9774  [parse distribute representation, self attenti...
# 9775  [proceeding th international conference logic ...
# 9776  [evaluate natural language inference, natural ...
# 9777  [foundation term quantum natural language proc...
#
#                                             Top_n_words  Probability  \
# 0     language - network - natural - representation ...     0.000000
# 1     language - network - natural - representation ...     0.000000
# 2     language - network - natural - representation ...     0.000000
# 3     language - network - natural - representation ...     0.000000
# 4     neuron - dendrite - typilus - apical - neuronb...     1.000000
# ...                                                 ...          ...
# 9773  dialogue - dialog - conversational - conversat...     0.799214
# 9774  parse - dependencyparse - parser - parsing - d...     0.592367
# 9775  logic - programming - constraint - internation...     0.565558
# 9776  inference - natural - reasoning - statisticall...     0.697182
# 9777  quantum - computer - move - term - categorical...     0.023240
#
#       Representative_document
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 9773                    False
# 9774                    False
# 9775                    False
# 9776                    False
# 9777                    False
#
# [9778 rows x 8 columns]

# %%
nlp_ttl_topic_model.visualize_topics()

# %% [markdown]
# ## save model

# %%
cc_topic_model.save("cc_abstract_bertopic_model_with_preprocessing")

# %%
cc_ttl_topic_model.save("cc_title_bertopic_model_with_preprocessing")

# %%
nlp_topic_model.save("nlp_abstract_bertopic_model_with_preprocessing")

# %%
nlp_ttl_topic_model.save("nlp_title_bertopic_model_with_preprocessing")
# Out:
# /Users/moyi/opt/anaconda3/envs/wins-project-bert/lib/python3.8/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning:
#
# Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
